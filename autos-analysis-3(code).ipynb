# %%
# %store -r dfc

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
dfc
# Out:
#                dateCrawled                                          name  \
# 0      2016-03-24 11:52:17                                    Golf_3_1.6
# 1      2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2      2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3      2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4      2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                    ...                                           ...
# 371523 2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524 2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525 2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526 2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527 2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  datetime64[ns]
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          371528 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              371528 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                371528 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             371528 non-null  object
# ...

# %%
dfc.isnull().mean()*100
# Out:
# dateCrawled            0.0
# name                   0.0
# seller                 0.0
# offerType              0.0
# price                  0.0
# abtest                 0.0
# vehicleType            0.0
# yearOfRegistration     0.0
# gearbox                0.0
# powerPS                0.0
# model                  0.0
# kilometer              0.0
# monthOfRegistration    0.0
# fuelType               0.0
# brand                  0.0
# notRepairedDamage      0.0
# dateCreated            0.0
# nrOfPictures           0.0
# postalCode             0.0
# lastSeen               0.0
# dtype: float64

# %% [markdown]
# # 1) The memory usage of the data is around 6.1 mb.How can we reduce the memory usage of the data set?

# %%
dfc.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
dfc.drop(["dateCrawled"],axis=1,inplace=True)

# %%
dfc.drop(["dateCreated"],axis=1,inplace=True)

# %%
dfc.drop(["postalCode"],axis=1,inplace=True)

# %%
dfc.drop(["lastSeen"],axis=1,inplace=True)

# %%
dfc["price"]=dfc["price"].astype(np.int32)

# %%
dfc["kilometer"]=dfc["kilometer"].astype(np.int32)

# %%
dfc["monthOfRegistration"]=dfc["monthOfRegistration"].astype(np.int8)

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   name                 371528 non-null  object
#  1   seller               371528 non-null  object
#  2   offerType            371528 non-null  object
#  3   price                371528 non-null  int32
#  4   abtest               371528 non-null  object
#  5   vehicleType          371528 non-null  object
#  6   yearOfRegistration   371528 non-null  int64
#  7   gearbox              371528 non-null  object
#  8   powerPS              371528 non-null  int64
#  9   model                371528 non-null  object
#  10  kilometer            371528 non-null  int32
#  11  monthOfRegistration  371528 non-null  int8
#  12  fuelType             371528 non-null  object
#  13  brand                371528 non-null  object
#  14  notRepairedDamage    371528 non-null  object
# ...

# %% [markdown]
# # 2) What is the Average price of vehicle by fuel type and gearbox type.Give a plot

# %%
avg_power=dfc.groupby(["vehicleType","gearbox"])["powerPS"].mean()
plt.subplots(figsize=(10,6))
avg_power.plot(kind="bar")
plt.xlabel("vehicleType and gearbox type")
plt.ylabel("average power")
plt.title("avg power of vehicletype and gearbox")
plt.show()

# %% [raw]
# andere vehicles are the most expensive, followed by petrol vehicles, diesel vehicles, LPG vehicles, and CNG vehicles. Automatic vehicles are also more expensive than manual vehicles.

# %% [markdown]
# # 3) What is the Average power of a vehicle by vehicle type and gearbox type.Give a plot

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.barplot(x='vehicleType', y='powerPS', hue='gearbox', palette='husl', data=dfc)
ax.set_title("Mean power of vehicles by type and gearbox")
ax.set_xlabel("VEHICLE TYPE")
ax.set_ylabel("MEAN POWER")
plt.show()

# %% [raw]
# From the plot, we see that automatic Coupe cars have the higher mean power.

# %% [markdown]
# # 4) What is the Average price of a vehicle by brand as well as vehicle type.Use heatmap to explain this

# %%
avg_price = dfc.groupby(['brand', 'vehicleType'])['price'].mean().unstack()


plt.figure(figsize=(12, 8))
sns.heatmap(avg_price, annot=True, cmap='YlGnBu', fmt=".0f", cbar_kws={'label': 'Average Price'})
plt.title('Average Price by Brand and Vehicle Type')
plt.xlabel('Vehicle Type')
plt.ylabel('Brand')
plt.show()
